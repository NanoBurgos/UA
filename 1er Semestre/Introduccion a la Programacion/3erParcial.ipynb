# %% [markdown]
# <a href="https://colab.research.google.com/github/NanoBurgos/Introduccion_a_la_Programacion/blob/main/3erParcial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Ejercicio 1**
# Desarrollo el siguiente Ejercicio utilizando Dev C++
# Diseñar un programa que solicite a su usuario un valor no negativo n y visualice la siguiente salida (n = 6):
# 1 2 3 4 5 6
#
# 1 2 3 4 5
#
# 1 2 3 4
#
# 1 2 3
#
# 1 2
#
# 1
#
# En cuanto al formato
# 1. Incluir en la línea de comentarios nombre y apellido del alumno centrado en la pantalla de la sgte. manera: 2 pts
# ******************************************
# Nombre del Alumno – Parcial 3
# ******************************************
# 2. Colocar un color de fondo y un color de letra, tanto para la visualización de los datos : 4 pts
# En cuanto a la sintaxis
# 1. Declaración correcta de variables:  2 pts
# 2. Estructura General del Programa:  2 pts
# Dejar las tabulaciones correspondientes, se tendrá en cuenta el ordenamiento en el código
# 3. Guardar correctamente el programa según las indicaciones: 1 pts.
# 4. Procesos: 10 pts
# 5. Sintaxis correcta – Reglas Generales: 2 pts
# 6. Salida correcta del programa: 2 pts
# Incluir mensajes por pantalla tanto para el ingreso como para la salida de los datos
# Se tendrá en cuenta el formato de impresión, dejando las tabulaciones indicadas
#
# Guardar el archivo como ejercicio1-apellidonombre adjuntar el archivo que contiene el código fuente.

# %% [markdown]
#       #include<iostream> // necesitamos para cin y cout
#       #include<cstdlib> //biblioteca standar de c para usar system para cambiar el color
#       using namespace std; //para no escribir std:: antes de cada funcion
#       int main(){
#         //el nombre pedia como comentario pero puse como una impresion por que tenia errores de codificacion
#         cout<<"******************************************"<<endl;
#         cout<<"     Luciano Burgos  Parcial 3            "<<endl;
#         cout<<"******************************************"<<endl;
#
#         int n; //declaramos donde se va a guardar lo que introduce el usurio
#
#         cout<<"Ingrese un numero positivo: "<<endl; //le mostramos la instruccion
#         cin>>n; //guardamos lo que introduce
#
#         while (n<0){ //hacemos un bucle que mientras se ingrese numeros negaticos
#         //vuelve a pedir que reingrese, para que el programa no se corte de una cuando se ingesa un negatiov
#         cout<<"ERROR, Ingrese solo numeros positivos: "<<endl;
#         cin>> n;
#         }
#
#         cout<<"\n El numero valido introducido fue: "<<n<<"; esta es su salida correspondiente: "<<endl;
#
#         int aux=n; //declaramos la variable auxiliar que nos va a ayudar en el bucle
#
#         //en el momento que vamos a visualizar la salida, vamos a cambiar el color
#
#         system("color b5"); //cambiamos el color de del fondo y de la letra
#         //hice un doble bucle, uno para que la variable auxiliar disminuya cada vez
#         //otro para que se imprime la cantidad de veces de la variable auxiliar
#         for(int aux=n; aux>0; aux=aux-1){
#           for(int i=1; i<=aux; i=i+1){
#             cout<<i<<" ";
#           }
#           cout<<"\n";//salto de linea para que no salga todo en una sola linea
#         }
#
#         return 0;
#       }

# %% [markdown]
# # **Ejercicio 2**
# La fábrica le asignó a sus productos las siguientes claves:
#
# Clave del producto Descripción del producto Costo del producto
#
# 2345        |     Computadora escritorio   |  $ 7500
#
# 1876        |     Impresora láser          |  $ 500
#
# 4316        |     Mouse                    |  $ 10
#
# Realiza un programa en lenguaje C++ que permita capturar repetidamente la clave de un producto utilizando una estructura cíclica
# En cada iteración, el programa debe:
#
# - Solicitar al usuario la clave del producto.
#
# - Desplegar la descripción y el costo del producto correspondiente.
#
# - En caso de que la clave no exista, mostrar el mensaje: "Producto no encontrado".
#
# - Preguntar al usuario si desea consultar otro producto y continuar el ciclo mientras la respuesta sea afirmativa.
#
# - El programa finaliza cuando el usuario indique que no desea realizar más consultas.
#
# - Formato requerido
# - Incluir un encabezado en comentarios con el nombre del estudiante centrado:
#
# ******************************************
#       Nombre del Alumno – Parcial 3
# ******************************************
# - Usar colores diferentes para:
#
# La entrada de datos
#
# La visualización de los resultados
#
# - Mantener orden, tabulación y claridad en el código.
#
# Nombre del archivo
# Guardar el programa como:
# ejercicio2-apellidonombre

# %% [markdown]
#       //******************************************
#       //      Luciano Burgos  Parcial 3
#       //******************************************
#       #include<iostream> // necesitamos para usar cin y cout
#       #include<cstdlib> //biblioteca standar de c para usar system para cambiar el color
#       using namespace std; //para no escribir std:: antes de cada funcion
#       int main(){
#
#         //declaramos las variables que vamos a usar
#         int clave_del_producto, costo;
#         //char descripcion_de_producto;
#         /*iba a usar una variable char ya que no hay string, pero al final use otro
#         metodo por que char, solo guarda la primera letra de la palabra*/
#
#         int continuar = 1; //nuestra bandera, si cambia corta el bucle
#
#         while(continuar == 1){ //bucle que se repite indefinidamente hasta que cortemos
#
#           system("color b5"); //cambiamos el color cuando leemos la entrada de datos
#           cout<<"\nIngrese la clave del producto: ";
#           cin>>clave_del_producto; //guardamos lo que ingresa el usuario
#
#           //condiciones de producto no encontrado
#           if(clave_del_producto!=2345 && clave_del_producto!=1876 && clave_del_producto!=4316){
#             cout<<"Producto no encontrado "<<endl;
#           }
#           else{
#
#             system("color d6");//cmbiamos el color cuando mostramos la salida
#             cout<<"***************************************"<<endl;
#             cout<<"Descripcion: "<<endl;
#
#             //ponemos los diferentes productos del inventario, cada uno con su nombre y precio
#             //que seran usados en caso de que se introduzca su codigo correspondiente
#             if(clave_del_producto==2345){
#               costo = 7500;
#               cout<<"Computadora de escritorio";
#             }
#
#             if(clave_del_producto==1876){
#               costo = 500;
#               cout<<"Impresora Laser";
#             }
#
#             if(clave_del_producto==4316){
#               costo = 10;
#               cout<<"Mouse";
#             }
#
#           cout<<"\nSu Costo es: "<<costo<<" $ "<<endl;
#           }
#
#
#           cout<<"***************************************"<<endl;
#
#           //preguntamos al usuario si quiere consultar algo mas
#           //si ingresa cualquier numero distinto de uno, corta el bucle
#           cout<<"Desea ingresar otro producto? (Si=1 No=2)";
#           cin>>continuar; //guardamos la respuesta del usuario
#
#           system("cls"); //limpiamos la pantalla despues de cada consulta
#           //por si otro usuario quiere hacer una consulta, para que no tenga
#           //que ver las consultas que otras personas hicieron
#
#         }
#
#         system("color 07"); //volvemos el color a la normalidad
#         cout<<"\nGracias por usar nuestros servicios, Vuelva pronto"; //mensaje de despedida
#
#         return 0;
#       }

# %% [markdown]
# # **3er Parcial del Grupo 81**
#
# // Cargar una matriz 3x3 y mostrar:
#
# // 1. La suma de cada columna.
#
# // 2. La suma de la diagonal principal.
#
#       Algoritmo sin_titulo
#         Definir matriz, suma_columnas, suma_diagonal Como Real
#         Definir f, c, i, j Como Entero
#
#         suma_columnas = 0
#         suma_diagonal = 0
#
#
#         f=3
#         c=3
#
#         Dimension matriz[f,c]
#
#         //cargamos la matriz
#         Para i=1 Hasta f Con Paso 1 Hacer
#           Para j=1 Hasta c Con Paso 1 Hacer
#             Escribir "Ingrese el elemento [", i ,"][", j ,"]: "
#             Leer matriz[i,j]
#           FinPara
#         FinPara
#
#         //mostramos la matriz cargada
#         Para i=1 Hasta f Con Paso 1 Hacer
#           Para j=1 Hasta c Con Paso 1 Hacer
#             Escribir matriz[i,j]," "
#           FinPara
#           Escribir " "
#         FinPara
#
#         //calculo de la suma de cada columna
#         Para j=1 Hasta c Con Paso 1 Hacer
#           suma_columnas=0
#           Para i=1 Hasta f Con Paso 1 Hacer
#             suma_columnas = suma_columnas + matriz[i,j]
#           FinPara
#           Escribir "La suma de la columna ",j," es: ", suma_columnas
#         FinPara
#
#         //calculo de la suma de la diagonal proncipal
#         Para j=1 Hasta c Con Paso 1 Hacer
#           Para i=1 Hasta f Con Paso 1 Hacer
#             Si i==j Entonces
#               suma_diagonal = suma_diagonal + matriz[i,j]
#             FinSi
#           FinPara
#         FinPara
#
#         EScribir "LA suma de la diagonal principal es : ",suma_diagonal
#
#       FinAlgoritmo
