# %% [markdown]
# <a href="https://colab.research.google.com/github/NanoBurgos/Introduccion_a_la_Programacion/blob/main/clase9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Tipos de Datos**
#
# **Datos Simples:**
# Estandar(int, real, float, char)
# Definido por el programador
#
# **Estructurados**
# Estaticos: array o arreglo, matriz
# Dinamicos: pila, cola, grafo, arbol
#
# # **Definicion de Arreglo:**
# Es una estructura de datos que almacena bajo el mismo nombre (variable) una coleccion de datos del mismo tipo
#
# Caracteristicas de los arreglos:
# - Es una secuencia de posiciones de la memoria central a las que se puede acceder directamente
# - Contienen datos del mismo tipo
# - Pueden ser seleccionados individualmente
# - Almacena los elementos en posiciones contiguas de memoria
# - Tienen un mismo nombre de variable
# - Para hacer referencia a esos elementos se utiliza un indice
#
# **(Pregunta de examen)** Le memoria se define en tiempo de compilacion,

# %% [markdown]
# # **Llenado de un Vector**
#
# Metodo 1
#
# Metodo 2
#
# Metodo 3

# %% [markdown]
# Ordenamiento de un Vector
# Doble Bucle anidado

# %% [markdown]
# //Almacenar 5 numeros en un vector , almacenarlos en otro vector en orden inverso al vector original e imprimir el vector resultante
#
#       Algoritmo Ejercicio1_2
# 	Definir vectorA, vectorB, x como Entero
#
# 	Dimension vectorA[15]
# 	Dimension vectorB[15]
#
# 	iaux = 15
#
# 	Para x=1 Hasta 15 Con Paso 1 Hacer
# 		Escribir "Ingrese el valor de la posicion: ",x," del primer vector:"
# 		Leer vectorA[x]
# 	FinPara
#
# 	Para x=1 Hasta 15 Con Paso 1 Hacer
# 		vectorB[iaux] = vectorA[x]
# 		iaux = iaux - 1
# 	FinPara
#
# 	Para x=1 Hasta 15 Con Paso 1 Hacer
# 		Escribir "El valor del vector B Inverso en la posicion: ",x," es: ",vectorB[x]
# 	FinPara
#
# 	Escribir "Vector Original  | Vector inverso"
# 	Para i=1 Hasta 15 con Paso 1 Hacer
# 		Escribir "[",vectorA[i],"]                 [",vectorB[i],"]"
# 	FinPara
#
#     FinAlgoritmo

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# //Se tienen almacenados en la memoria dos vectoes M y N de 5 elementos cada uno. Hacer un algoritmo que escriba la palabra IGUALES si ambos vectores son iguales y DIFERENTES si no lo son
#
#       Algoritmo sin_titulo
#         Definir vectorM, vectorN,cont Como Entero
#
#         Dimension vectorM[5]
#         Dimension vectorN[5]
#         ban=1
#
#         Escribir "**********************************************************"
#         Escribir "                 Datos del primer vector                  "
#         Escribir "**********************************************************"
#
#         Para cont = 1 Hasta 5 Con Paso 1 Hacer
#           Escribir "Ingrese el valor de la posicion: ",cont," del primer vector: "
#           Leer vectorM[cont]
#         FinPara
#
#         Escribir "**********************************************************"
#         Escribir "                 Datos del segundo vector                 "
#         Escribir "**********************************************************"
#
#         Para cont = 1 Hasta 5 Con Paso 1 Hacer
#           Escribir "Ingrese el valor de la posicion: ",cont," del segundo vector: "
#           Leer vectorN[cont]
#         FinPara
#
#         Para cont = 1 Hasta 5 Con Paso 1 Hacer
#           Si vectorM[cont]<>vectorN[cont] Entonces
#             ban = 0
#           FinSi
#         FinPara
#
#         Escribir "**********************************************************"
#         Escribir "                        Resultados                        "
#         Escribir "**********************************************************"
#
#         Si ban = 0 Entonces
#           Escribir "Los vectores son Diferentes"
#         SiNo
#           Escribir "Los vectores son iguales"
#         FinSi
#
#
#
#
#
#
#       FinAlgoritmo

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# //Diseñe un algoritmo que escriba SI si el vector esta ordenado ascendentemente o NO si el vector no esta ordenado
#
#       Algoritmo sin_titulo
#         Definir vectorA, cont, vectorB Como Entero
#
#         Dimension vectorA[10]
#         ban = 1
#
#         Para cont = 1 Hasta 10 Con Paso 1 Hacer
#           Escribir "Ingrese el valor de la posicion: ",cont," del vector A: "
#           Leer vectorA(cont)
#         FinPara
#
#         Para cont = 1 Hasta 9 Con Paso 1 Hacer
#           Para cont_B = (cont+1) Hasta 10 Con Paso 1 Hacer
#
#             Si vectorA[cont] > vectorA[cont_B]
#               ban =0
#             FinSi
#
#           FinPara
#
#         FinPara
#
#         Si ban = 1 Entonces
#           Escribir "SI"
#
#         SiNo
#           Escribir "NO"
#         FinSi
#
#       FinAlgoritmo

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# //Diseñe un algoritmo que lea un numero cualquiera y lo busque en el vector X, el cual tiene almacenados 8 elementos. Escribir la posicion donde se encuentra almacenado el numero en el vector o el mensaje NO si no lo encuentra. Busqueda Secuencial
#
#       Algoritmo Ejercicio4_2
#         Definir vectorA, vectorB, cont, num, ban Como Entero
#         Dimension vectorA[8]
#
#         Escribir "Ingrese el valor que desea buscar dentro del vector: "
#         Leer num
#
#         ban = 0
#
#         Para cont= 1 Hasta 8 con Paso 1 Hacer
#           Escribir "Ingresa el elemento <",cont,"> del vector: "
#           Leer vectorA[cont]
#         FinPara
#
#         Para cont= 1 Hasta 8 con Paso 1 Hacer
#           Si num == vectorA[cont] Entonces
#             ban =1
#           FinSi
#         FinPara
#
#         Si ban = 0 Entonces
#           Escribir "NO"
#         SiNo
#           Escribir "SI"
#         FinSi
#
#       FinAlgoritmo

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# //Diseñe un algoritmo que lea dos vectores A y B de 10 elementos cada uno y multiplique el primer elemento de A con el ultimo elemento de B y luego el segundo elemento de A por el diecinueveavo elemento de B y así sucesivamente hasta llegar al veinteavo elemento de A por el primer elemento de B. El resultado de la multiplicación almacenarlo en un vector C.
#
#       Algoritmo Ejercicio5_2
#         Definir vectorA, vectorB, vectorC, cont Como Entero
#         n=5
#
#         Dimension vectorA[n], vectorB[n], vectorC[n]
#
#         aux=5
#
#         Para cont = 1 Hasta n Con Paso 1 Hacer
#           Escribir "Ingresa el elemento <",cont,"> del primer vector: "
#           Leer vectorA[cont]
#         FinPara
#
#         Para cont = 1 Hasta n Con Paso 1 Hacer
#           Escribir "Ingresa el elemento <",cont,"> del segundo vector: "
#           Leer vectorB[cont]
#         FinPara
#
#         Para cont = 1 Hasta n Con Paso 1 Hacer
#           vectorC[cont] = vectorA[cont] * vectorB[aux]
#           aux = aux - 1
#         FinPara
#
#         Para cont = 1 Hasta n Con Paso 1 Hacer
#           Escribir "La multiplicacion de los valores vectorA * vectorB en la posicion: ",cont,"es:  ", vectorC[cont]
#         FinPara
#
#       FinAlgoritmo

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# // 1)Llenar dos vectores A y B de 10 elementos cada uno, sumar el elemento uno del vector A con el elemento uno del vector B y así sucesivamente hasta 10, almacenar el resultado en un vector C, e imprimir el vector resultante.
#
#     Algoritmo sin_titulo
#       Dimension  vector_a[10], vector_b[10], vector_c[10];
#
#       Escribir "Carga los elementos del vector A: "
#       Para i = 1 Hasta 10 con Paso 1 Hacer
#         Escribir "Ingresa el elemento <",i,"> del vector A: "
#         Leer vector_a[i]
#       FinPara
#
#       Escribir "Carga los elementos del vector B: "
#       Para i = 1 Hasta 10 con Paso 1 Hacer
#         Escribir "Ingresa el elemento <",i,"> del vector B: "
#         Leer vector_b[i]
#       FinPara
#
#       Para i=1 Hasta 10 con Paso 1 Hacer
#         vector_c[i] = vector_a[i] + vector_b[i]
#       FinPara
#
#       Escribir "El vector Resultante sera: "
#       Para i = 1 Hasta 10 con Paso 1 Hacer
#         Escribir "[",vector_c[i],"]"
#       FinPara
#
#
#     FinAlgoritmo

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# // 2)Llenar un vector de 10 elementos, imprimir la posición y el valor del elemento mayor almacenado en el vector. Suponga que todos los elementos del vector son diferentes.
#
#       Algoritmo sin_titulo
#         Definir may, pos Como Entero
#
#         may = -99999
#
#         Dimension vector[10]
#
#         Escribir "Ingresa los elementos del vector: "
#
#         Para i = 1 Hasta 10 con Paso 1 Hacer
#           Escribir "Ingresa el elemento <",i,"> del vector: "
#           Leer vector[i]
#         FinPara
#
#         Para i = 1 Hasta 10 con Paso 1 Hacer
#           si vector[i] > may Entonces
#             may = vector[i]
#             pos = i
#           FinSi
#         FinPara
#
#         Escribir "La posicion del elemeno mayor del vector es: ", pos
#         Escribir "El valor del mayor elemento del vector es: ", may
#
#
#
#       FinAlgoritmo

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# // 3)Almacenar 10 números en un vector, elevar al cuadrado cada valor almacenado en el vector, almacenar el resultado en otro vector. Imprimir el vector original y el vector resultante.
#
#       Algoritmo sin_titulo
#
#         Dimension vector[10], vector_cuadrado[10];
#
#         Escribir "Ingresa los elementos del vector: "
#
#         Para i = 1 Hasta 10 con Paso 1 Hacer
#           Escribir "Ingresa el elemento <",i,"> del vector: "
#           Leer vector[i]
#         FinPara
#
#         Para i = 1 Hasta 10 con Paso 1 Hacer
#           vector_cuadrado[i] = vector[i] * vector[i]
#         FinPara
#
#         Escribir "Vector Original  | Vector al Cuadrado"
#         Para i=1 Hasta 10 con Paso 1 Hacer
#           Escribir "[",vector[i],"]                 [",vector_cuadrado[i],"]"
#         FinPara
#
#       FinAlgoritmo

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# //4) Almacenar 10 números en un vector, imprimir cuantos son ceros, cuantos son negativos, cuantos positivos. Imprimir además la suma de los negativos y la suma de los positivos
#
#
#       Algoritmo Ejercicio4
#         Definir vector, suma_positivos, suma_negativos Como Real
#         Definir cont_positivos, cont_negativos, cont_ceros Como Entero
#         Dimension vector[10]
#
#         suma_positivos = 0
#         suma_negativos = 0
#
#         Escribir "Ingresa los elementos del vector: "
#
#         Para i = 1 Hasta 10 con Paso 1 Hacer
#           Escribir "Ingresa el elemento <",i,"> del vector: "
#           Leer vector[i]
#         FinPara
#
#         Para i = 1 Hasta 10 con Paso 1 Hacer
#
#           Si vector[i] == 0 Entonces
#             cont_ceros = cont_ceros + 1
#           FinSi
#
#           Si vector[i] > 0 Entonces
#             cont_positivos = cont_positivos + 1
#             suma_positivos = suma_positivos + vector[i]
#           FinSi
#
#           Si vector[i] < 0 Entonces
#             cont_negativos = cont_negativos + 1
#             suma_negativos = suma_negativos + vector[i]
#           FinSi
#
#         FinPara
#
#         Escribir "La cantidad de 0 (ceros) en el vector es de: ",cont_ceros
#         Escribir "La cantidad de nuimeros positivos en el vector es de: ", cont_positivos
#         Escribir "La cantidad de nuimeros negativos en el vector es de: ", cont_negativos
#         Escribir"..........................................................................."
#         Escribir "La suma de numeros positivos es de: ", suma_positivos
#         Escribir "La suma de numeros negativos es de: ", suma_negativos
#
#
#
#       FinAlgoritmo

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
